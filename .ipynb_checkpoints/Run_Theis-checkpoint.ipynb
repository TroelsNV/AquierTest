# %%
# import needed modules
from IPython.display import Image
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import (LogLocator, NullFormatter)
import pandas as pd
import numpy as np
import AquiferTest as at

# %% [markdown]
# ## Dataset 1:
# Confined aquifer

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
PW_rad = 0.01 # this radius is not meaningfull, and it is only for visualization
Q = 6/(60*60)

# %%
S = 0.1
T = 2.2e-4*50
t = np.logspace(0, 6, num=100)
O1_sim = at.T1945(Q, T, S, 200, t)
O2_sim = at.T1945(Q, T, S, 150, t)
O3_sim = at.T1945(Q, T, S, 50, t)
O4_sim = at.T1945(Q, T, S, 10, t)

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

# plot the solution as a function of t
ax.loglog(t,O1_sim,'r-', label = '200 m')
ax.loglog(t,O2_sim,'b-', label = '150 m')
ax.loglog(t,O3_sim,'k-', label = '50 m')
ax.loglog(t,O4_sim,'y-', label = '10 m')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

#ax.set_title(file_name1)
ax.legend()
ax.set_ylim((1e-3, 1))
ax.set_xlim((1e3, 1e6))
ax.set_xlabel('t [s]')
ax.set_ylabel('sænkning [m]')
# Out:
# Text(0, 0.5, 'sænkning [m]')

# %% [markdown]
# ## Dataset 2:
# Large diameter well, initial part of dataset affected

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name2 = os.path.join('data','2.dat')
data2 = read_data(file_name2)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
S, T = 0.0004123505631832143, 0.4262021324891104
PW_sim = at.T1945(Q, T, S, PW_rad, data2['O1'][:,0])
O1_sim = at.T1945(Q, T, S, data2['O1_dist'], data2['O1'][:,0])
O2_sim = at.T1945(Q, T, S, data2['O2_dist'], data2['O2'][:,0])

# %% [markdown]
# ### plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data2['O1'][:,0],data2['O1'][:,1],'r*', label = 'O1')
ax.loglog(data2['O2'][:,0],data2['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data2['O1'][:,0],O1_sim,'r-', label = 'O1')
ax.loglog(data2['O2'][:,0],O2_sim,'b-', label = 'O2')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name1)
ax.legend()
ax.set_ylim((1e-3, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %% [markdown]
# ## Dataset 3:
# Partially penetrating pumping well, be carefull with observations close to the pumping well. e.g. try to estimate the radius of influence from the vertical component

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name3 = os.path.join('data','3.dat')
data3 = read_data(file_name3)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
S, T = 0.00019243026281883332, 0.30544486161719575
PW_sim = at.T1945(Q, T, S, PW_rad, data3['O1'][:,0])
O1_sim = at.T1945(Q, T, S, data3['O1_dist'], data3['O1'][:,0])
O2_sim = at.T1945(Q, T, S, data3['O2_dist'], data3['O2'][:,0])

# %% [markdown]
# ### plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data3['O1'][:,0],data3['O1'][:,1],'r*', label = 'O1')
ax.loglog(data3['O2'][:,0],data3['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data3['O1'][:,0],O1_sim,'r-', label = 'O1')
ax.loglog(data3['O2'][:,0],O2_sim,'b-', label = 'O2')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name1)
ax.legend()
ax.set_ylim((1e-3, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %% [markdown]
# ## Dataset 4
# confined aquifer with skin around pumpingwell

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name4 = os.path.join('data','4.dat')
data4 = read_data(file_name4)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
S, T = 0.001114460981576255, 1.2382899795291722
PW_sim = at.T1945(Q, T, S, PW_rad, data4['O1'][:,0])
O1_sim = at.T1945(Q, T, S, data4['O1_dist'], data4['O1'][:,0])
O2_sim = at.T1945(Q, T, S, data4['O2_dist'], data4['O2'][:,0])

# %% [markdown]
# ### Plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data4['O1'][:,0],data4['O1'][:,1],'r*', label = 'O1')
ax.loglog(data4['O2'][:,0],data4['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data4['O1'][:,0],O1_sim,'r-', label = 'O1')
ax.loglog(data4['O2'][:,0],O2_sim,'b-', label = 'O2')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name4)
ax.legend()
ax.set_ylim((1e-3, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %% [markdown]
# ## Dataset 5:
# Leaky aquifer, use HANTUSCH (1960) after Theis

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name5 = os.path.join('data','5.dat')
data5 = read_data(file_name5)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
# Theis Solution:
S, T = 0.0004, 0.48
PW_sim1 = at.T1945(Q, T, S, PW_rad, data5['O1'][:,0])
O1_sim1 = at.T1945(Q, T, S, data5['O1_dist'], data5['O1'][:,0])
O2_sim1 = at.T1945(Q, T, S, data5['O2_dist'], data5['O2'][:,0])

# %% [markdown]
# ### plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data5['O1'][:,0],data5['O1'][:,1],'r*', label = 'O1')
ax.loglog(data5['O2'][:,0],data5['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data5['O1'][:,0],O1_sim1,'r-', label = 'O1')
ax.loglog(data5['O2'][:,0],O2_sim1,'b-', label = 'O2')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name5)
ax.legend()
ax.set_ylim((1e-3, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %%
# Hantusch and Jacob (1955):
S, T, bm, km = 0.0004, 0.48, 1, 1e-6 
PW_sim1 = at.HJ1955(Q, T, S, PW_rad, data5['O1'][:,0], bm, km)
O1_sim1 = at.HJ1955(Q, T, S, data5['O1_dist'], data5['O1'][:,0], bm, km)
O2_sim1 = at.HJ1955(Q, T, S, data5['O2_dist'], data5['O2'][:,0], bm, km)

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data5['O1'][:,0],data5['O1'][:,1],'r*', label = 'O1')
ax.loglog(data5['O2'][:,0],data5['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data5['O1'][:,0],O1_sim1,'r-', label = 'O1')
ax.loglog(data5['O2'][:,0],O2_sim1,'b-', label = 'O2')

# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name5)
ax.legend()
ax.set_ylim((1e-3, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %% [markdown]
# ## dataset 6:
# unconfined aquifer with shallow piezometers

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name6 = os.path.join('data','6.dat')
data6 = read_data(file_name6)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
data6['O1_dist'], data6['O2_dist']
# Out:
# (10.0, 25.0)

# %%
# Theis Solution:
Sy, S, T = 0.10308764079580357, 5e-3, 0.4165157203870851
PW_sim1 = at.T1945(Q, T, Sy, PW_rad, data6['O1'][:,0])
O1_sim1 = at.T1945(Q, T, Sy, data6['O1_dist'], data6['O1'][:,0])
O2_sim1 = at.T1945(Q, T, Sy, data6['O2_dist'], data6['O2'][:,0])

PW_sim2 = at.T1945(Q, T, S, PW_rad, data6['O1'][:,0])
O1_sim2 = at.T1945(Q, T, S, data6['O1_dist'], data6['O1'][:,0])
O2_sim2 = at.T1945(Q, T, S, data6['O2_dist'], data6['O2'][:,0])

# %% [markdown]
# ### plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data6['O1'][:,0],data6['O1'][:,1],'r*', label = 'O1')
ax.loglog(data6['O2'][:,0],data6['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data6['O1'][:,0],O1_sim1,'r-', label = 'O1 late')
ax.loglog(data6['O2'][:,0],O2_sim1,'b-', label = 'O2 late')

# plot the solution as a function of t
ax.loglog(data6['O1'][:,0],O1_sim2,'r--', label = 'O1 early')
ax.loglog(data6['O2'][:,0],O2_sim2,'b--', label = 'O2 early')


# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name5)
ax.legend()
ax.set_ylim((1e-5, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')

# %% [markdown]
# Early responses are difficult to fit

# %% [markdown]
# ## dataset 7:
# unconfined aquifer with deep piezometers

# %%
# read dataset in the file "1.dat" located in the subfolder "data"
file_name7 = os.path.join('data','7.dat')
data7 = read_data(file_name7)
PW_rad = 0.1 # this radius is not meaningfull, and it is only for visualization
Q = 1
b = 10

# %%
# Theis Solution:
Sy, S, T = 0.10308764079580357, 4e-4, 0.4165157203870851
PW_sim1 = at.T1945(Q, T, Sy, PW_rad, data7['O1'][:,0])
O1_sim1 = at.T1945(Q, T, Sy, data7['O1_dist'], data7['O1'][:,0])
O2_sim1 = at.T1945(Q, T, Sy, data7['O2_dist'], data7['O2'][:,0])

PW_sim2 = at.T1945(Q, T, S, PW_rad, data7['O1'][:,0])
O1_sim2 = at.T1945(Q, T, S, data7['O1_dist'], data7['O1'][:,0])
O2_sim2 = at.T1945(Q, T, S, data7['O2_dist'], data7['O2'][:,0])

# %% [markdown]
# ### plot the data:

# %%
f1, ax = plt.subplots(figsize=(15,5))

# plot the datasets as a function of t
#ax.loglog(data1['O1'][:,0],data1['O1'][:,1]*Q/T,'r*', label = 'O1')
#ax.loglog(data1['O2'][:,0],data1['O2'][:,1]*Q/T,'b*', label = 'O2')

ax.loglog(data7['O1'][:,0],data7['O1'][:,1],'r*', label = 'O1')
ax.loglog(data7['O2'][:,0],data7['O2'][:,1],'b*', label = 'O2')


# plot the solution as a function of t
ax.loglog(data7['O1'][:,0],O1_sim1,'r-', label = 'O1 late')
ax.loglog(data7['O2'][:,0],O2_sim1,'b-', label = 'O2 late')

# plot the solution as a function of t
ax.loglog(data7['O1'][:,0],O1_sim2,'r--', label = 'O1 early')
ax.loglog(data7['O2'][:,0],O2_sim2,'b--', label = 'O2 early')


# make the figure more readable
ax.set_xscale('log')
ax.grid(True,which="both")

ax.set_title(file_name7)
ax.legend()
ax.set_ylim((1e-5, 10.0))
ax.set_xlabel('t')
ax.set_ylabel(data1['columns'][1])
# Out:
# Text(0, 0.5, 'Drawdown')
